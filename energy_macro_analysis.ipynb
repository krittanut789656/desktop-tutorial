# %% [markdown]
# # Energy Sector Analysis & Macro Crisis (2000-2026)
# ## DADS 5001: Data Analytics and Data Science Tools and Programming — Mini-Project
#
# **หัวข้อ:** วิเคราะห์พลวัตหุ้นกลุ่มพลังงานสหรัฐฯ และไทย ท่ามกลางวิกฤตภูมิรัฐศาสตร์และเศรษฐกิจมหภาค (2000-2026)
#
# **Pipeline:**
# 1. `01_data_collection.ipynb` — Data Collection (Yahoo Finance + FRED API)
# 2. `02_data_cleaning.ipynb` — Data Cleaning & Feature Engineering
# 3. `03_eda_analysis.ipynb` — 20 Insights EDA (Storytelling with Data)
#
# **How to run:** Execute each notebook in order (01 -> 02 -> 03).
#
# ---
#
# ## Quick Navigation
#
# | ACT | Insights | Theme |
# |-----|----------|-------|
# | **ACT 1: The Global Stage** | 1-5 | Oil correlation, indexed prices, inflation, dollar effect, VIX |
# | **ACT 2: US vs Thailand** | 6-10 | Upstream battle, crisis resilience, dividends, cumulative returns |
# | **ACT 3: Crisis Deep Dive** | 11-15 | Russia-Ukraine event study, Iran 2025, volatility, COVID recovery |
# | **ACT 4: Policy & Strategy** | 16-20 | Oil fund gap, Sharpe ratios, industrial production, portfolio allocation |

# %% [markdown]
# ## Executive Summary: 20 Insights & Hypothesis Testing
#
# | # | Insight | Hypothesis | Result |
# |---|---------|-----------|--------|
# | 1 | Oil-Stock Correlation | All energy stocks positively correlate with Brent | **True** — COP highest, PTG lowest |
# | 2 | 26-Year Price Evolution | Oil dictates macro trend for all 10 stocks | **True** — but individual divergences exist |
# | 3 | Energy CPI vs Stocks | Rising energy inflation erodes real stock returns | **True** |
# | 4 | Dollar vs Energy | Strong USD hurts oil prices | **True** — Thai stocks face double headwind |
# | 5 | VIX vs Energy Vol | Market fear amplifies energy sector volatility | **True** |
# | 6 | PTTEP vs COP | COP tracks oil rallies better than PTTEP | **True** — Higher oil-beta |
# | 7 | Thai Resilience | Thai stocks are safe havens in crises | **False** — COVID-19 showed comparable losses |
# | 8 | Upstream/Downstream | Supply shocks widen upstream premium | **True** |
# | 9 | Cumulative Returns | US energy delivers higher total returns | **True** |
# | 10 | Dividend Yield | Thai energy offers higher yields | **True** — Compensates for lower capital gains |
# | 11 | Russia-Ukraine Event | US majors outperform during war | **True** |
# | 12 | Iran Crisis Event | Pattern echoes Russia-Ukraine | **True** |
# | 13 | Volatility Boxplot | COVID-19 most volatile period | **True** |
# | 14 | V-Shape Recovery | Energy stocks recovered rapidly post-COVID | **True** — COP recovered fastest |
# | 15 | Max Drawdown | Great Recession caused deepest drawdowns | **True** |
# | 16 | Thai Oil Fund | Policy dampens domestic price swings | **True** — But widens fiscal gap |
# | 17 | Sharpe Ratio | Risk-adjusted returns vary across crises | **True** |
# | 18 | Industrial Production | Industrial output drives oil demand | **True** |
# | 19 | Correlation Matrix | US stocks are tightly coupled | **True** — r>0.6 among US |
# | 20 | Portfolio Strategy | US upstream best war-time risk/reward | **True** |

# %% [markdown]
# ## Action Plan: Policy & Investment Strategy
#
# ### Investment Recommendations:
# 1. **War-Time Overweight:** Allocate 40-50% to US upstream (COP, XOM) during geopolitical crises
# 2. **Income Strategy:** Thai energy stocks (PTT, BCP) provide 3-7% dividend yields
# 3. **Diversification Hedge:** PTTEP provides EM upstream exposure with lower correlation to US majors
# 4. **Risk Management:** Maintain 10% VIX-linked protection during war periods
# 5. **Currency Watch:** Monitor Dollar Index — strong USD periods require underweighting THB positions
#
# ### Policy Implications:
# 1. Thailand's Oil Fund effectively dampens domestic price volatility but creates fiscal risk
# 2. Upstream/downstream spread analysis can serve as early warning for energy subsidy pressure
# 3. Energy transition policy should consider geopolitical risk premium in fossil fuel equities

# %% [markdown]
# ## Compliance Checklist (DADS 5001)
#
# | Requirement | Status |
# |-------------|--------|
# | Data > 100 rows | Data collected via Yahoo Finance + FRED |
# | Pandas used extensively | All data manipulation via Pandas |
# | Matplotlib/Seaborn used | 20 figures with Matplotlib + Seaborn |
# | Weekly data interval | Weekly data (2000-2026) |
# | Multiple data sources | Yahoo Finance + FRED (2 sources) |
# | 20 Insights EDA | 20 figures organized in 4 ACTs |
# | Decluttered visualizations | No gridlines clutter, no top/right spines, white bg |
# | Proper labeling | Fig number, title, subtitle, units, source on every chart |
# | No tutorial duplication | Original analysis, no copied tutorials |
# | Storytelling structure | 4-ACT narrative: Global -> US vs TH -> Crises -> Strategy |
# | Error handling | Handles missing data, timezone, currency adjustment |
# | Feature engineering | Indexed prices, returns, volatility, crisis labels, FX adjustment |
